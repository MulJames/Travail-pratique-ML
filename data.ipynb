# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
malaria = pd.read_csv('global-malaria.csv')

# %%
malaria.head()
# Out:
#            Region    1990    1991    1992    1993    1994    1995    1996  \
# 0     Afghanistan      93     189     239     108     211     175     175
# 1  African Region  588508  607330  620445  638935  650973  668983  688268
# 2         Albania       0       0       0       0       0       0       0
# 3         Algeria       9       9      12      12       8       7       5
# 4  American Samoa       0       0       0       0       0       0       0
#
#      1997    1998  ...    2010    2011    2012    2013    2014    2015  \
# 0     240     563  ...     377     390      94     143     228     284
# 1  708186  726403  ...  804031  764244  727320  694438  655614  631381
# 2       0       0  ...       0       0       0       0       0       0
# 3       5       2  ...       0       0       0       0       0       0
# 4       0       0  ...       0       0       0       0       0       0
#
#      2016    2017    2018    2019
# 0     388     399     466     530
# ...

# %%
malaria.columns
# Out:
# Index(['Region', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
sns.barplot(data=malaria, x='Region', y='1990')
plt.show()

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Region  228 non-null    object
#  1   1990    228 non-null    int64
#  2   1991    228 non-null    int64
#  3   1992    228 non-null    int64
#  4   1993    228 non-null    int64
#  5   1994    228 non-null    int64
#  6   1995    228 non-null    int64
#  7   1996    228 non-null    int64
#  8   1997    228 non-null    int64
#  9   1998    228 non-null    int64
#  10  1999    228 non-null    int64
#  11  2000    228 non-null    int64
#  12  2001    228 non-null    int64
#  13  2002    228 non-null    int64
#  14  2003    228 non-null    int64
#  15  2004    228 non-null    int64
#  16  2005    228 non-null    int64
#  17  2006    228 non-null    int64
#  18  2007    228 non-null    int64
#  19  2008    228 non-null    int64
#  20  2009    228 non-null    int64
#  21  2010    228 non-null    int64
# ...

# %%
malaria['1992']
# Out:
# 0         239
# 1      620445
# 2           0
# 3          12
# 4           0
#         ...
# 223    463295
# 224     15027
# 225      5693
# 226      8724
# 227      2210
# Name: 1992, Length: 228, dtype: int64

# %%
malaria['1992'].mean()
# Out:
# np.float64(19490.06140350877)

# %%
malaria['1992'].mode()
# Out:
# 0    0
# Name: 1992, dtype: int64

# %%
malaria.isnull().sum()
# Out:
# Region    0
# 1990      0
# 1991      0
# 1992      0
# 1993      0
# 1994      0
# 1995      0
# 1996      0
# 1997      0
# 1998      0
# 1999      0
# 2000      0
# 2001      0
# 2002      0
# 2003      0
# 2004      0
# 2005      0
# 2006      0
# 2007      0
# 2008      0
# 2009      0
# 2010      0
# 2011      0
# 2012      0
# 2013      0
# 2014      0
# 2015      0
# 2016      0
# 2017      0
# 2018      0
# 2019      0
# dtype: int64

# %%
malaria['1992'].fillna(malaria['1992'].mean(), inplace=True)

# %%
sns.countplot(x='Region', data=malaria)
plt.title('Toutes Les Regions')
plt.show()
